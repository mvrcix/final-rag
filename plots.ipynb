# %%
# BERTSCORE SUMMARY RAG
import matplotlib.pyplot as plt 
import seaborn as sns
  
# create data 
x = [64, 128, 256, 512, 1024] 
precision = [0.8263152837753296, 0.8251173496246338, 0.8274421691894531,  0.8237146735191345, 0.826926589012146]
recall = [0.8716518878936768, 0.8729556798934937, 0.8743659853935242, 0.8759896755218506, 0.8770440816879272]
f1 = [0.848196804523468, 0.8482387065887451, 0.8500943183898926, 0.8488799333572388, 0.8510797023773193]


  
# plot lines 
x_ticks = range(len(x))
fig, ax = plt.subplots()
ax.xaxis.set_ticklabels(x)
ax.xaxis.set_ticks(x)

ax.plot(x, precision, label = "Precision", marker='o', markersize=4) 
ax.plot(x, recall, label = "Recall", marker='o', markersize=4) 
ax.plot(x, f1, label = "F1-score", marker='o', markersize=4) 
plt.legend(loc='upper right', bbox_to_anchor=(1.0, 0.9)) 
plt.show()
# Out:
# /tmp/ipykernel_48159/1111187474.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.xaxis.set_ticklabels(x)

# %%
#BERTSCORE MULTIMODAL RAG
import matplotlib.pyplot as plt 
import seaborn as sns
  
# create data 
x = [64, 128, 256, 512, 1024] 
precision = [0.8472023010253906, 0.8501728773117065, 0.8406693935394287, 0.6476620435714722, 0.5633915662765503]
recall = [0.8912742733955383, 0.8911694288253784, 0.8877487182617188, 0.6890915632247925, 0.5984768271446228]
f1 = [0.868465781211853, 0.8668534159660339, 0.8632946014404297, 0.6672734022140503, 0.5800262689590454]

  
# plot lines 
x_ticks = range(len(x))
fig, ax = plt.subplots()
ax.xaxis.set_ticklabels(x)
ax.xaxis.set_ticks(x)

ax.plot(x, precision, label = "Precision", marker='o', markersize=4) 
ax.plot(x, recall, label = "Recall", marker='o', markersize=4) 
ax.plot(x, f1, label = "F1-score", marker='o', markersize=4) 
plt.legend(loc='upper right', bbox_to_anchor=(1.0, 0.9)) 
plt.show()
# Out:
# /tmp/ipykernel_48159/215487656.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.xaxis.set_ticklabels(x)

# %%
# LANGSMITH SUMMARY RAG
import matplotlib.pyplot as plt 
import seaborn as sns
  
# create data 
x = [64, 128, 256, 512, 1024] 
coherence = [0.82, 0.77, 0.92, 0.85, 0.84]
cot = [0.48, 0.55, 0.52, 0.48, 0.56]
relevance = [0.69, 0.70, 0.74, 0.81, 0.68]


  
# plot lines 
x_ticks = range(len(x))
fig, ax = plt.subplots()
ax.xaxis.set_ticklabels(x)
ax.xaxis.set_ticks(x)

ax.plot(x, coherence, label = "Coherence", marker='o', markersize=4) 
ax.plot(x, cot, label = "Contextual Accuracy", marker='o', markersize=4) 
ax.plot(x, relevance, label = "Relevance", marker='o', markersize=4) 
plt.legend(loc='upper right') 
plt.show()
# Out:
# /tmp/ipykernel_48159/2340616940.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.xaxis.set_ticklabels(x)

# %%
# LANGSMITH SUMMARY RAG
import matplotlib.pyplot as plt 
import seaborn as sns
  
# create data 
x = [64, 128, 256, 512, 1024] 
coherence = [0.79, 0.75, 0.87, 0.78, 0.74]
cot = [0.36, 0.49, 0.37, 0.07, 0.23]
relevance = [0.77, 0.69, 0.73, 0.66, 0.52]


  
# plot lines 
x_ticks = range(len(x))
fig, ax = plt.subplots()
ax.xaxis.set_ticklabels(x)
ax.xaxis.set_ticks(x)

ax.plot(x, coherence, label = "Coherence", marker='o', markersize=4) 
ax.plot(x, cot, label = "Contextual Accuracy", marker='o', markersize=4) 
ax.plot(x, relevance, label = "Relevance", marker='o', markersize=4) 
# plt.legend(loc='upper right') 
plt.legend(loc='upper right', bbox_to_anchor=(1.0, 0.5)) 

plt.show()
# Out:
# /tmp/ipykernel_48159/2652202879.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.xaxis.set_ticklabels(x)

# %% [markdown]
# K VALUES

# %%
# bertscore Text only
import matplotlib.pyplot as plt 
import seaborn as sns
  
# create data 
x = [2, 4, 6, 8] 
precision = [0.8257353901863098, 0.8274421691894531, 0.8232242465019226
, 0.8188591003417969]
recall = [0.873911440372467, 0.8743659853935242, 0.8733057975769043,  0.8698954582214355]
f1 = [0.848944902420044, 0.8500943183898926, 0.8473535776138306, 0.8434463739395142]


  
# plot lines 
x_ticks = range(len(x))
fig, ax = plt.subplots()
ax.xaxis.set_ticklabels(x)
ax.xaxis.set_ticks(x)

ax.plot(x, precision, label = "Precision", marker='o', markersize=4) 
ax.plot(x, recall, label = "Recall", marker='o', markersize=4) 
ax.plot(x, f1, label = "F1-score", marker='o', markersize=4) 
plt.legend(loc='upper right', bbox_to_anchor=(1.0, 0.8)) 
plt.show()
# Out:
# /tmp/ipykernel_48400/3980095537.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.xaxis.set_ticklabels(x)

# %%
# bertscore Multimodal
import matplotlib.pyplot as plt 
import seaborn as sns
  
# create data 
x = [2, 4, 6, 8] 
precision = []
recall = []
f1 = []


  
# plot lines 
x_ticks = range(len(x))
fig, ax = plt.subplots()
ax.xaxis.set_ticklabels(x)
ax.xaxis.set_ticks(x)

ax.plot(x, precision, label = "Precision", marker='o', markersize=4) 
ax.plot(x, recall, label = "Recall", marker='o', markersize=4) 
ax.plot(x, f1, label = "F1-score", marker='o', markersize=4) 
plt.legend(loc='upper right', bbox_to_anchor=(1.0, 0.9)) 
plt.show()

# %%
#Langsmith Text only
x = [2,4,6,8] 
coherence = [0.96, 0.92, 0.81, 0.85]
cot = [0.52, 0.52, 0.56, 0.44]
relevance = [0.72, 0.74, 0.76, 0.68]


  
# plot lines 
x_ticks = range(len(x))
fig, ax = plt.subplots()
ax.xaxis.set_ticklabels(x)
ax.xaxis.set_ticks(x)

ax.plot(x, coherence, label = "Coherence", marker='o', markersize=4) 
ax.plot(x, cot, label = "Contextual Accuracy", marker='o', markersize=4) 
ax.plot(x, relevance, label = "Relevance", marker='o', markersize=4) 
# plt.legend(loc='upper right') 
plt.legend(loc='upper right', bbox_to_anchor=(1.0, 1.0)) 

plt.show()
# Out:
# /tmp/ipykernel_48159/1774827844.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.xaxis.set_ticklabels(x)

# %%
#Langsmith Multimodal
x = [2,4,6,8] 
coherence = [0.90, 0.87, 0.88, 0.85]
cot = [0.34, 0.37, 0.33, 0.19]
relevance = [0.72, 0.73, 0.68, 0.69]


  
# plot lines 
x_ticks = range(len(x))
fig, ax = plt.subplots()
ax.xaxis.set_ticklabels(x)
ax.xaxis.set_ticks(x)

ax.plot(x, coherence, label = "Coherence", marker='o', markersize=4) 
ax.plot(x, cot, label = "Contextual Accuracy", marker='o', markersize=4) 
ax.plot(x, relevance, label = "Relevance", marker='o', markersize=4) 
# plt.legend(loc='upper right') 
plt.legend(loc='upper right', bbox_to_anchor=(1.0, 1.0)) 

plt.show()
# Out:
# /tmp/ipykernel_48159/1442849719.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.xaxis.set_ticklabels(x)
